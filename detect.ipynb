# %% [markdown]
# ## Prediction

# %%
# Imports

from headliners_CXRForeignViewer.lib.model_mapper import YoloViewer

# %% [markdown]
# ## Data processing

# %%
# Data processing logic

# %% [markdown]
# ## Making prediction

# %%
# Training from zero

train_data = 'hhhh'
data = 'some data'
model1 = YoloViewer()
model1.train(train_data, 'my_model')
model1.predict(data, 'output')

# Starting our pretrained model

model2 = YoloViewer(trained=True)
model2.predict(data, 'output')

# Starting different pretrained model

model2 = YoloViewer(calculated_weights='path/to/weights')
model2.predict(data, 'output')
